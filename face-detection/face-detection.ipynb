# %% [markdown]
# # Face Detection

# %%
import cv2                
import random
import numpy as np
import matplotlib.pyplot as plt  
# %matplotlib inline                               

random.seed(8675309)

# %%
# load and shuffled human faces
human_faces = np.array(glob("humans_dataset/*/*"))
random.shuffle(human_faces)

# print statistics about the dataset
print('There are %d total human images.' % len(human_files))

# use pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

img = cv2.imread(random.choice(human_files))
# convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# try to find face
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('# of faces detected:', len(faces))

# create bounding box for each face
for (x,y,w,h) in faces:
    # add box to the RGB image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display result
plt.imshow(cv_rgb)
plt.show()
# Out:
# There are 13233 total human images.
# # of faces detected: 2
